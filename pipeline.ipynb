# %%
from pipeline import run

run(
    start_date=None,
    end_date=None,
    out_dir=r"D:\Shared\test\bmw"
)
# Out:
# loading C:\Users\JK\AppData\Local\Temp\bmw_gen\2021-10-03\json\https___business_inquirer_net--nlp--applied
# loading C:\Users\JK\AppData\Local\Temp\bmw_gen\2021-10-03\json\https___edition_cnn_com_business--nlp--applied
# loading C:\Users\JK\AppData\Local\Temp\bmw_gen\2021-10-03\json\https___www_bworldonline_com_category_banking-finance_--nlp--applied
# loading C:\Users\JK\AppData\Local\Temp\bmw_gen\2021-10-03\json\https___www_bworldonline_com_category_corporate_--nlp--applied
# loading C:\Users\JK\AppData\Local\Temp\bmw_gen\2021-10-03\json\https___www_bworldonline_com_category_economy_--nlp--applied
# loading C:\Users\JK\AppData\Local\Temp\bmw_gen\2021-10-03\json\https___www_bworldonline_com_category_top-stories_--nlp--applied
# loading C:\Users\JK\AppData\Local\Temp\bmw_gen\2021-10-03\json\https___www_cnbc_com_finance_--nlp--applied
# loading C:\Users\JK\AppData\Local\Temp\bmw_gen\2021-10-03\json\https___www_gmanetwork_com_news_money--nlp--applied
# ...
